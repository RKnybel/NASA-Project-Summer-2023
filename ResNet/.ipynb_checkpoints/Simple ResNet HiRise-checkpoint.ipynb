# %% [markdown]
# Setup

# %%
import tensorflow as tf
import numpy as np
import PIL
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model, Sequential
# Out:
# 2023-09-25 16:04:54.497707: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Load data

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  'DataSet/images',
  batch_size = batch_size,
  image_size = (img_height, img_width),
  shuffle = True,
  seed = 321,
  validation_split = 0.2,
  subset = "training"
)
# Out:
# Found 11977 files belonging to 7 classes.
# Using 9582 files for training.
# 2023-09-25 16:04:56.805511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.811873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.812010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.812975: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.813091: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.813193: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.938240: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.938379: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.938498: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:1013] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-25 16:04:56.938592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1638] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9983 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  'hirise-oversample',
  batch_size = batch_size,
  image_size = (img_height, img_width),
  shuffle = False,
  seed = 321,
  validation_split = 0.2,
  subset = "validation",
)
# Out:
# Found 11977 files belonging to 7 classes.
# Using 2395 files for validation.

# %%
#list of class names:
class_lookup = ['other', 'crater', 'dark dune', 'slope streak', 'bright dune', 'impact ejecta', 'swiss cheese', 'spider']
for i in range(1, len(class_lookup)):
    print(str(i) + ' ' + class_lookup[i])
# Out:
# 1 crater
# 2 dark dune
# 3 slope streak
# 4 bright dune
# 5 impact ejecta
# 6 swiss cheese
# 7 spider

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
#show examples of different classes

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    label = class_names[labels[i]]
    plt.title(label + ": " + class_lookup[int(label)])
    plt.axis("off")
# Out:
# 2023-09-25 16:04:57.435236: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [9582]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-25 16:04:57.435523: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [9582]
# 	 [[{{node Placeholder/_4}}]]

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)
# 2023-09-25 16:04:58.075013: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [9582]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-25 16:04:58.075306: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [9582]
# 	 [[{{node Placeholder/_0}}]]

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras.layers import *

class ResNetBlock(Layer):

  def __init__(self, out_channels, first_stride = 1):
    super().__init__()

    first_padding = 'same'
    if first_stride != 1:
      first_padding = 'valid'

    self.conv_sequence = Sequential([
      Conv2D(out_channels, 3, first_stride, padding = first_padding),
      BatchNormalization(),
      ReLU(),
      Conv2D(out_channels, 3, 1, padding = 'same'),
      BatchNormalization(),
      ReLU()
    ])

  def call(self, inputs):
    x = self.conv_sequence(inputs)
    
    if x.shape == inputs.shape:
      x = x + inputs
    return x

layer = ResNetBlock(4)
print(layer)
# Out:
# <__main__.ResNetBlock object at 0x7fc5ac3868c0>

# %%
class ResNet(Model):
  def __init__(self):
    super(ResNet, self).__init__()
    
    self.conv_1 = Sequential([
      Rescaling(1./255, input_shape=(img_height, img_width, 3)),
      Conv2D(64, 7, 2),
      ReLU(),
      MaxPooling2D(3, 2)])
    
    self.resnet_chains = Sequential(
      [ResNetBlock(64), ResNetBlock(64)] +
      [ResNetBlock(128, 2), ResNetBlock(128)] +
      [ResNetBlock(256, 2), ResNetBlock(256)] +
      [ResNetBlock(512, 2), ResNetBlock(512)])
  
    self.out = Sequential([
      GlobalAveragePooling2D(),
      Dense(24)])
    
  def call(self, x):
    x = self.conv_1(x)
    x = self.resnet_chains(x)
    x = self.out(x)
    return x

model = ResNet()
print(model)
# Out:
# <__main__.ResNet object at 0x7fc5b4179cc0>

# %%
for (img, label) in train_ds:
  print(model(img).numpy().shape, label.numpy())
  break
# Out:
# 2023-09-25 16:04:58.241604: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [9582]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-25 16:04:58.241898: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [9582]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-25 16:04:58.320901: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8903
# (32, 24) [0 6 0 2 0 1 0 0 0 0 1 2 2 0 4 2 2 6 5 0 5 0 0 3 4 5 5 0 3 0 3 0]
# 2023-09-25 16:04:59.223433: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
print(model.summary())
# Out:
# Model: "res_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 54, 54, 64)        9472
#
#  sequential_10 (Sequential)  (32, 5, 5, 512)           11004672
#
#  sequential_11 (Sequential)  (32, 24)                  12312
#
# =================================================================
# Total params: 11,026,456
# Trainable params: 11,018,776
# Non-trainable params: 7,680
# _________________________________________________________________
# None

# %%
model.compile(optimizer = 'adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience = 5, monitor = 'loss')

# %%
history = model.fit(
  train_ds,
  epochs = 40,
  validation_data = val_ds,
  callbacks=[es]
)
# Out:
# Epoch 1/40
# 2023-09-25 16:05:02.502018: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fc4e65b1b60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-09-25 16:05:02.502039: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-09-25 16:05:02.506041: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-09-25 16:05:02.607237: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 300/300 [==============================] - ETA: 0s - loss: 1.4128 - accuracy: 0.4991
# 2023-09-25 16:05:24.527685: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [2395]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-25 16:05:24.527956: I tensorflow/core/common_runtime/executor.cc:1209] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [2395]
# 	 [[{{node Placeholder/_4}}]]
# 300/300 [==============================] - 27s 62ms/step - loss: 1.4128 - accuracy: 0.4991 - val_loss: 4.6364 - val_accuracy: 0.0263
# Epoch 2/40
# 300/300 [==============================] - 17s 55ms/step - loss: 1.2142 - accuracy: 0.5495 - val_loss: 4.8831 - val_accuracy: 0.0706
# Epoch 3/40
# 300/300 [==============================] - 16s 55ms/step - loss: 1.0198 - accuracy: 0.6335 - val_loss: 7.8148 - val_accuracy: 0.1942
# Epoch 4/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.8546 - accuracy: 0.7013 - val_loss: 2.2505 - val_accuracy: 0.3511
# Epoch 5/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.7170 - accuracy: 0.7555 - val_loss: 4.0151 - val_accuracy: 0.1207
# Epoch 6/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.6165 - accuracy: 0.7890 - val_loss: 8.3676 - val_accuracy: 0.0484
# Epoch 7/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.5352 - accuracy: 0.8193 - val_loss: 2.3812 - val_accuracy: 0.2998
# Epoch 8/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.4617 - accuracy: 0.8447 - val_loss: 2.0053 - val_accuracy: 0.4255
# Epoch 9/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.4015 - accuracy: 0.8658 - val_loss: 2.6357 - val_accuracy: 0.2668
# Epoch 10/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.3537 - accuracy: 0.8793 - val_loss: 1.3860 - val_accuracy: 0.6159
# Epoch 11/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.2954 - accuracy: 0.8982 - val_loss: 2.3386 - val_accuracy: 0.3695
# Epoch 12/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.2496 - accuracy: 0.9153 - val_loss: 10.2397 - val_accuracy: 0.1136
# Epoch 13/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.2132 - accuracy: 0.9284 - val_loss: 2.7878 - val_accuracy: 0.3566
# Epoch 14/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.1918 - accuracy: 0.9349 - val_loss: 1.1252 - val_accuracy: 0.6534
# Epoch 15/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.1594 - accuracy: 0.9439 - val_loss: 1.4843 - val_accuracy: 0.6551
# Epoch 16/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.1425 - accuracy: 0.9512 - val_loss: 0.6634 - val_accuracy: 0.7745
# Epoch 17/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.1167 - accuracy: 0.9580 - val_loss: 2.1361 - val_accuracy: 0.5315
# Epoch 18/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0881 - accuracy: 0.9700 - val_loss: 1.3669 - val_accuracy: 0.6100
# Epoch 19/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.1019 - accuracy: 0.9639 - val_loss: 3.0775 - val_accuracy: 0.4058
# Epoch 20/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0652 - accuracy: 0.9777 - val_loss: 6.0764 - val_accuracy: 0.3374
# Epoch 21/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0851 - accuracy: 0.9708 - val_loss: 4.9133 - val_accuracy: 0.3507
# Epoch 22/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0624 - accuracy: 0.9794 - val_loss: 13.6313 - val_accuracy: 0.1269
# Epoch 23/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0520 - accuracy: 0.9825 - val_loss: 6.5824 - val_accuracy: 0.4063
# Epoch 24/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0490 - accuracy: 0.9840 - val_loss: 3.4850 - val_accuracy: 0.5854
# Epoch 25/40
# 300/300 [==============================] - 16s 53ms/step - loss: 0.0426 - accuracy: 0.9857 - val_loss: 4.2024 - val_accuracy: 0.5624
# Epoch 26/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0364 - accuracy: 0.9886 - val_loss: 0.3814 - val_accuracy: 0.8990
# Epoch 27/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0514 - accuracy: 0.9817 - val_loss: 5.9340 - val_accuracy: 0.2714
# Epoch 28/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0397 - accuracy: 0.9869 - val_loss: 5.8219 - val_accuracy: 0.2630
# Epoch 29/40
# 300/300 [==============================] - 16s 54ms/step - loss: 0.0384 - accuracy: 0.9881 - val_loss: 1.2499 - val_accuracy: 0.7837
# Epoch 30/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.9313 - val_accuracy: 0.7841
# Epoch 31/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.0285 - accuracy: 0.9898 - val_loss: 1.3451 - val_accuracy: 0.7098
# Epoch 32/40
# 300/300 [==============================] - 17s 55ms/step - loss: 0.0259 - accuracy: 0.9921 - val_loss: 1.8846 - val_accuracy: 0.7182
# Epoch 33/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.0357 - accuracy: 0.9877 - val_loss: 4.4448 - val_accuracy: 0.4217
# Epoch 34/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.0383 - accuracy: 0.9865 - val_loss: 0.7075 - val_accuracy: 0.8276
# Epoch 35/40
# 300/300 [==============================] - 16s 55ms/step - loss: 0.0426 - accuracy: 0.9858 - val_loss: 9.0272 - val_accuracy: 0.2885

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

numEpochs = 35
epochs_range = range(numEpochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# generate the confusion matrix
y_pred = []  # store predicted labels
y_true = []  # store true labels

# iterate over the dataset
for image_batch, label_batch in val_ds:   # use dataset.unbatch() with repeat
    # append true labels
    y_true.append(label_batch)
    # compute predictions
    preds = model.predict(image_batch)
    # append predicted labels
    y_pred.append(np.argmax(preds, axis = - 1))

# convert the true and predicted labels into tensors
correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

confusion = confusion_matrix(correct_labels, predicted_labels)
# Out:
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 217ms/step

# %%
print(correct_labels)
print(predicted_labels)
# Out:
# tf.Tensor([3 3 3 ... 6 6 6], shape=(2395,), dtype=int32)
# tf.Tensor([3 2 3 ... 6 6 6], shape=(2395,), dtype=int64)

# %%
# visualize the confusion matrix
plt.figure(figsize=(7, 7))
sns.heatmap(confusion, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
